# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("applications.csv")
display(df.head())
# Out:
#             Applied at   Amount  Age   Gender                      Industry  \
# 0  11.30.2022 10:26:37  12000.0   29  Чоловік                    Blockchain
# 1  11.30.2022 10:26:39      NaN   36  Чоловік  Public services / Government
# 2  11.30.2022 10:26:58   7500.0   34  Чоловік          Adtech / Advertising
# 3  11.30.2022 10:27:31   1500.0   23    Жінка                       Telecom
# 4  11.30.2022 10:27:34   8400.0   33    Жінка                    Automotive
#
#   Marital status  External Rating                       Education level  \
# 0          Other              8.0  Вища (бакалавр, спеціаліст, магістр)
# 1         Single              3.0  Вища (бакалавр, спеціаліст, магістр)
# 2         Single              4.0  Вища (бакалавр, спеціаліст, магістр)
# 3         Single              0.0  Вища (бакалавр, спеціаліст, магістр)
# 4         Single              6.0  Вища (бакалавр, спеціаліст, магістр)
#
#                       Location                      applicant_id
# 0  Івано-Франківськ чи область  99e7b0dc6cc05dd334d8f38dc26ce9b3
# 1                          NaN  63dfcf8e6904186650d6814279fbe42f
# 2              Київ чи область  10dbafaeb46c09e96b6987c03bbb3498
# 3             Львів чи область  5847ac62cc9eac5e323c2517dcc91ad1
# 4           Житомир чи область  5d21f3795b50de8e8f8f8d5f48b754f3

# %%
print(df.shape)
# Out:
# (13315, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13315 entries, 0 to 13314
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Applied at       13315 non-null  object
#  1   Amount           13272 non-null  float64
#  2   Age              13315 non-null  int64
#  3   Gender           13315 non-null  object
#  4   Industry         13315 non-null  object
#  5   Marital status   13315 non-null  object
#  6   External Rating  13243 non-null  float64
#  7   Education level  13282 non-null  object
#  8   Location         11540 non-null  object
#  9   applicant_id     13315 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.0+ MB

# %%
print(df.columns)
# Out:
# Index(['Applied at', 'Amount', 'Age', 'Gender', 'Industry', 'Marital status',
#        'External Rating', 'Education level', 'Location', 'applicant_id'],
#       dtype='object')

# %%
# 1.1 Прибери дублікати applicant_id

df.drop_duplicates(subset='applicant_id', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13278 entries, 0 to 13314
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Applied at       13278 non-null  object
#  1   Amount           13245 non-null  float64
#  2   Age              13278 non-null  int64
#  3   Gender           13278 non-null  object
#  4   Industry         13278 non-null  object
#  5   Marital status   13278 non-null  object
#  6   External Rating  13206 non-null  float64
#  7   Education level  13245 non-null  object
#  8   Location         11506 non-null  object
#  9   applicant_id     13278 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.1+ MB

# %%
# 1.2 В полі 'External Rating' заповни відсутні значення нулями

display(df[df['External Rating'].isna()])

df['External Rating'].fillna(0, inplace=True)
# Out:
#                 Applied at   Amount  Age   Gender              Industry  \
# 85     11.30.2022 10:38:01   2850.0   24  Чоловік            E-commerce
# 208    11.30.2022 11:05:17  16500.0   32  Чоловік  Adtech / Advertising
# 209    11.30.2022 11:05:25   6000.0   27  Чоловік              Big Data
# 210    11.30.2022 11:05:28   9900.0   21  Чоловік            E-commerce
# 211    11.30.2022 11:06:42   4500.0   30  Чоловік  Medtech / Healthcare
# ...                    ...      ...  ...      ...                   ...
# 12757     01.03.2023 22:00   2850.0   25    Жінка                 Media
# 13087     01.05.2023 22:34   2400.0   30  Чоловік               GameDev
# 13106     01.06.2023 02:50   9600.0   37  Чоловік            E-commerce
# 13303     01.08.2023 22:25   7500.0   26    Жінка  Medtech / Healthcare
# 13304     01.08.2023 22:35  13500.0   34  Чоловік  Medtech / Healthcare
#
#       Marital status  External Rating                       Education level  \
# 85           Married              NaN  Вища (бакалавр, спеціаліст, магістр)
# 208            Other              NaN  Вища (бакалавр, спеціаліст, магістр)
# 209           Single              NaN  Вища (бакалавр, спеціаліст, магістр)
# 210          Married              NaN  Вища (бакалавр, спеціаліст, магістр)
# 211           Single              NaN  Вища (бакалавр, спеціаліст, магістр)
# ...              ...              ...                                   ...
# 12757        Married              NaN  Вища (бакалавр, спеціаліст, магістр)
# 13087        Married              NaN  Вища (бакалавр, спеціаліст, магістр)
# 13106         Single              NaN  Вища (бакалавр, спеціаліст, магістр)
# 13303        Married              NaN  Вища (бакалавр, спеціаліст, магістр)
# 13304        Married              NaN  Вища (бакалавр, спеціаліст, магістр)
#
#                               Location                      applicant_id
# 85                    Львів чи область  2ba1eb28088c5b35d5689ebc31e2d24c
# 208                    Київ чи область  6354663b7fb7ae4ab7b050a9db99a7d4
# 209                Чернівці чи область  64de362d162615a4084953917918f9ba
# 210                    Київ чи область  70729c1d2dc288cd740f569edd38b54f
# 211                    Київ чи область  1395cbdbfcf8538df3c14639d29972ae
# ...                                ...                               ...
# 12757      Івано-Франківськ чи область  28de6b90a56c008f8b2f143482858b36
# 13087                  Київ чи область  7873ed35e9dc08f69908a1c747e19f63
# 13106                  Київ чи область  88a9720600d8c9f666707c1ea6fce03b
# 13303                  Київ чи область  570929ecff6eab12338c89b311eefdb8
# 13304  Ужгород чи Закарпатська область  35883a3c7e174a178c24b7ea2c18a89a
#
# [72 rows x 10 columns]

# %%
# 1.3 В полі 'Education level' заповни відсутні значення текстом “Середня”

df['Education level'] = df['Education level'].fillna('Середня')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13278 entries, 0 to 13314
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Applied at       13278 non-null  object
#  1   Amount           13245 non-null  float64
#  2   Age              13278 non-null  int64
#  3   Gender           13278 non-null  object
#  4   Industry         13278 non-null  object
#  5   Marital status   13278 non-null  object
#  6   External Rating  13278 non-null  float64
#  7   Education level  13278 non-null  object
#  8   Location         11506 non-null  object
#  9   applicant_id     13278 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.1+ MB

# %%
# 2. Додай до цього DataFrame дані з файлу industries.csv, а саме, рейтинги індустрій

df_ind = pd.read_csv("industries.csv")
display(df_ind)
# Out:
#                         Industry  Score
# 0                     Blockchain      0
# 1   Public services / Government     20
# 2           Adtech / Advertising     10
# 3                        Telecom     15
# 4                     Automotive     15
# 5                     E-commerce     15
# 6                          Media      5
# 7                           Інша     10
# 8                         Dating      5
# 9             Edtech / Education     15
# 10                         Legal     20
# 11                      Big Data     20
# 12                     Logistics     20
# 13                  Data Science     20
# 14             Fintech / Banking     20
# 15                        Mobile     15
# 16                     Insurance     10
# 17                           ERP     10
# 18                      Gambling      5
# 19              Machine Learning     20
# 20                   Agriculture     15
# 21                       GameDev     10
# 22          Medtech / Healthcare     15
# 23               Cloud Computing     20
# 24                      Embedded     10
# 25                        Travel      5
# 26                      Security     15
# 27                        Retail     10
# 28                 Manufacturing     15
# 29                      Hardware     15
# 30             High Load Systems     15
# 31                  Uberfication     10
# 32                   Real Estate     10
# 33            Internet of Things     15
# 34                    Geospatial     10
# 35                         AR/VR     10
# 36                      Robotics     10

# %%
merged = pd.merge(left=df,
                  right=df_ind,
                  on='Industry',
                  how='left')

display(merged.head())
# Out:
#             Applied at   Amount  Age   Gender                      Industry  \
# 0  11.30.2022 10:26:37  12000.0   29  Чоловік                    Blockchain
# 1  11.30.2022 10:26:39      NaN   36  Чоловік  Public services / Government
# 2  11.30.2022 10:26:58   7500.0   34  Чоловік          Adtech / Advertising
# 3  11.30.2022 10:27:31   1500.0   23    Жінка                       Telecom
# 4  11.30.2022 10:27:34   8400.0   33    Жінка                    Automotive
#
#   Marital status  External Rating                       Education level  \
# 0          Other              8.0  Вища (бакалавр, спеціаліст, магістр)
# 1         Single              3.0  Вища (бакалавр, спеціаліст, магістр)
# 2         Single              4.0  Вища (бакалавр, спеціаліст, магістр)
# 3         Single              0.0  Вища (бакалавр, спеціаліст, магістр)
# 4         Single              6.0  Вища (бакалавр, спеціаліст, магістр)
#
#                       Location                      applicant_id  Score
# 0  Івано-Франківськ чи область  99e7b0dc6cc05dd334d8f38dc26ce9b3      0
# 1                          NaN  63dfcf8e6904186650d6814279fbe42f     20
# 2              Київ чи область  10dbafaeb46c09e96b6987c03bbb3498     10
# 3             Львів чи область  5847ac62cc9eac5e323c2517dcc91ad1     15
# 4           Житомир чи область  5d21f3795b50de8e8f8f8d5f48b754f3     15

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13278 entries, 0 to 13277
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Applied at       13278 non-null  object
#  1   Amount           13245 non-null  float64
#  2   Age              13278 non-null  int64
#  3   Gender           13278 non-null  object
#  4   Industry         13278 non-null  object
#  5   Marital status   13278 non-null  object
#  6   External Rating  13278 non-null  float64
#  7   Education level  13278 non-null  object
#  8   Location         11506 non-null  object
#  9   applicant_id     13278 non-null  object
#  10  Score            13278 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 1.1+ MB

# %%
# 3. Розрахуй рейтинг заявки за наступними умовами:

# Якщо вік між 35 та 55, то до рейтингу додається 20 балів

filter_1 = ((merged['Age'] >= 35) & (merged['Age'] <= 55)) * 20
print(filter_1)
# Out:
# 0         0
# 1        20
# 2         0
# 3         0
# 4         0
#          ..
# 13273     0
# 13274     0
# 13275     0
# 13276     0
# 13277     0
# Name: Age, Length: 13278, dtype: int32

# %%
# Якщо заявка була подана не у вихідні, то до рейтингу додається 20 балів

merged['Applied at'] = pd.to_datetime(merged['Applied at'], format='mixed')
print(merged['Applied at'])
# Out:
# 0       2022-11-30 10:26:37
# 1       2022-11-30 10:26:39
# 2       2022-11-30 10:26:58
# 3       2022-11-30 10:27:31
# 4       2022-11-30 10:27:34
#                 ...
# 13273   2023-01-09 11:01:00
# 13274   2023-01-09 11:14:00
# 13275   2023-01-09 11:19:00
# 13276   2023-01-09 11:28:00
# 13277   2023-01-09 11:38:00
# Name: Applied at, Length: 13278, dtype: datetime64[ns]

# %%
filter_2 = ((merged['Applied at'].dt.day_name() != "Saturday") & (merged['Applied at'].dt.day_name() != "Sunday")) * 20
print(filter_2)
# Out:
# 0        20
# 1        20
# 2        20
# 3        20
# 4        20
#          ..
# 13273    20
# 13274    20
# 13275    20
# 13276    20
# 13277    20
# Name: Applied at, Length: 13278, dtype: int32

# %%
# Якщо одружений, то до рейтингу додається 20 балів

filter_3 = (merged['Marital status'] == "Married") * 20
print(filter_3)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 13273     0
# 13274    20
# 13275    20
# 13276     0
# 13277    20
# Name: Marital status, Length: 13278, dtype: int32

# %%
# Якщо знаходиться в Києві чи області, то до рейтингу додається 10 балів

filter_4 = (merged['Location'] == "Київ чи область") * 10
print(filter_4)
# Out:
# 0         0
# 1         0
# 2        10
# 3         0
# 4         0
#          ..
# 13273     0
# 13274     0
# 13275     0
# 13276     0
# 13277     0
# Name: Location, Length: 13278, dtype: int32

# %%
# Якщо 'External Rating' більше чи дорівнює 7, то до рейтингу додається 20 балів

filter_5 = (merged['External Rating'] >= 7) * 20
print(filter_5)
# Out:
# 0        20
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 13273     0
# 13274     0
# 13275     0
# 13276    20
# 13277    20
# Name: External Rating, Length: 13278, dtype: int32

# %%
# Якщо 'External Rating' менше чи дорівнює 2, то з рейтингу віднімається 20 балів

filter_6 = (merged['External Rating'] <= 2) * (-20)
print(filter_6)
# Out:
# 0         0
# 1         0
# 2         0
# 3       -20
# 4         0
#          ..
# 13273     0
# 13274     0
# 13275     0
# 13276     0
# 13277     0
# Name: External Rating, Length: 13278, dtype: int32

# %%
# Рейтинг - сума оцінок заявки по 6 критеріям

merged['Rating'] = merged['Score'] + filter_1 + filter_2 + filter_3 + filter_4 + filter_5 + filter_6
print(merged['Rating'])
# Out:
# 0        40
# 1        60
# 2        40
# 3        15
# 4        35
#          ..
# 13273    35
# 13274    40
# 13275    40
# 13276    55
# 13277    75
# Name: Rating, Length: 13278, dtype: int64

# %%
# Рейтинг дорівнює нулю, якщо відсутнє значення 'Amount' або якщо 'External Rating' дорівнює нулю

merged.loc[merged['Amount'].isna() | (merged['External Rating'] == 0), 'Rating'] = 0
merged[(merged['Amount'].isna()) | (merged['External Rating'] == 0)][['Amount', 'External Rating', 'Rating']]
# Out:
#         Amount  External Rating  Rating
# 1          NaN              3.0       0
# 3       1500.0              0.0       0
# 9          NaN              2.0       0
# 11     19800.0              0.0       0
# 17         NaN              2.0       0
# ...        ...              ...     ...
# 13233   5700.0              0.0       0
# 13236   1020.0              0.0       0
# 13238   4800.0              0.0       0
# 13266   7500.0              0.0       0
# 13267  13500.0              0.0       0
#
# [556 rows x 3 columns]

# %%
# Рейтинг має бути числом від 0 до 100

print(merged['Rating'].min())

merged.loc[merged['Rating'] < 0, 'Rating'] = 0
print(merged['Rating'].min())
# Out:
# -20
# 0

# %%
print(merged['Rating'].max())

merged.loc[merged['Rating'] > 100, 'Rating'] = 100
print(merged['Rating'].max())
# Out:
# 110
# 100

# %%
# 4. В результуючій таблиці залиши лише заявки з рейтингом більше нуля, ці заявки вважатимуться прийнятими

result_table = merged[merged['Rating'] > 0]

display(result_table.sort_values(by='Rating').head())
# Out:
#                Applied at   Amount  Age   Gender    Industry Marital status  \
# 4161  2022-12-04 19:19:00  21450.0   31  Чоловік    Gambling         Single
# 10394 2022-12-20 22:40:41   3900.0   33  Чоловік      Dating         Single
# 3514  2022-12-03 14:19:00   4800.0   23  Чоловік  E-commerce         Single
# 6543  2022-12-08 09:54:00   4200.0   23    Жінка    Gambling         Single
# 4505  2022-12-05 15:28:00   4500.0   28    Жінка      Dating         Single
#
#        External Rating                       Education level  \
# 4161               6.0  Вища (бакалавр, спеціаліст, магістр)
# 10394              1.0  Вища (бакалавр, спеціаліст, магістр)
# 3514               1.0  Вища (бакалавр, спеціаліст, магістр)
# 6543               2.0  Вища (бакалавр, спеціаліст, магістр)
# 4505               2.0  Вища (бакалавр, спеціаліст, магістр)
#
#                           Location                      applicant_id  Score  \
# 4161                           NaN  c8466c94b305a5374eb7c36fa5080b57      5
# 10394  Івано-Франківськ чи область  15e5e80fd0e876ec8e3a73e5bd86d0ff      5
# 3514               Київ чи область  5194bbc26a3f324a350d27678533f5fa     15
# 6543                           NaN  0478fa234970cc3b073dba07a2f46465      5
# 4505              Львів чи область  d579d2707ca40671659756f81ffcc1d8      5
#
#        Rating
# 4161        5
# 10394       5
# 3514        5
# 6543        5
# 4505        5

# %%
# 5. Дані з результуючої таблиці згрупуй за тижнем подачі заявки та виведи на графік середній рейтинг прийнятих заявок

result_table.loc[:, 'Applied at'] = result_table['Applied at'].dt.isocalendar().week
display(result_table.head())
# Out:
#    Applied at   Amount  Age   Gender              Industry Marital status  \
# 0          48  12000.0   29  Чоловік            Blockchain          Other
# 2          48   7500.0   34  Чоловік  Adtech / Advertising         Single
# 4          48   8400.0   33    Жінка            Automotive         Single
# 5          48  16500.0   31  Чоловік            E-commerce         Single
# 6          48   4200.0   30  Чоловік                 Media        Married
#
#    External Rating                       Education level  \
# 0              8.0  Вища (бакалавр, спеціаліст, магістр)
# 2              4.0  Вища (бакалавр, спеціаліст, магістр)
# 4              6.0  Вища (бакалавр, спеціаліст, магістр)
# 5              8.0  Вища (бакалавр, спеціаліст, магістр)
# 6              1.0  Вища (бакалавр, спеціаліст, магістр)
#
#                       Location                      applicant_id  Score  \
# 0  Івано-Франківськ чи область  99e7b0dc6cc05dd334d8f38dc26ce9b3      0
# 2              Київ чи область  10dbafaeb46c09e96b6987c03bbb3498     10
# 4           Житомир чи область  5d21f3795b50de8e8f8f8d5f48b754f3     15
# 5              Київ чи область  f720bf9c5c4c3e10a8568c1699847696     15
# 6              Київ чи область  0aaf59fb3ef90f50ccd4800312e5c271      5
#
#    Rating
# 0      40
# 2      40
# 4      35
# 5      65
# 6      35

# %%
weekly_avg_rating = result_table.groupby('Applied at')[['Rating']].mean().round(1)
display(weekly_avg_rating)
# Out:
#             Rating
# Applied at
# 1             51.5
# 2             51.9
# 48            50.6
# 49            49.4
# 50            49.8
# 51            47.0
# 52            50.9

# %%
print(weekly_avg_rating.plot(kind='bar', title='Weekly average rating of accepted applications'))
# Out:
# Axes(0.125,0.11;0.775x0.77)
